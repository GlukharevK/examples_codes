# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_excel('orders.xls')

# %%
df = df.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4'], axis=1)
df = df[:-1]

# %%
pattern = r"(\d{6}).*?(\d{2}.\d{2}.\d{4}) \d*:\d*:\d*, (.*), (.*)"

# %%
new_df = pd.DataFrame()

# %%
temp = df['Заказ клиента, Клиент, Пометка удаления'].str.findall(pattern)

# %%
order_client = []
date = []
dealer = []
delete_note = []

# %%
new_df['Заказ клиента'] = 0
new_df['Дата заказа'] = 0
new_df['Дилер'] = 0
new_df['Пометка удаления'] = 0

# %%
for i in temp:
    print(i[0][0])
    new_df['Заказ клиента'].append(pd.Series(i[0][0]))
    new_df['Дата заказа'].append(pd.Series(i[0][1]))
    new_df['Дилер'].append(pd.Series(i[0][2]))
    new_df['Пометка удаления'].append(pd.Series(i[0][3]))
# Out:
# 101822
# 101822
# 101823
# 101753
# 101753
# 101828
# 101828
# 101828
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101831
# 101832
# 101832
# 101832
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101824
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101839
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101841
# 101597
# 101597
# 101597
# 101597
# 101855
# 101855
# 101857
# 101857
# 101858
# 101868
# 101868
# 101868
# 101868
# 101868
# 101868
# 101868
# 101868
# 101868
# ...

# %%
pd.Series(temp[0][0][0])
# Out:
# 0    101822
# dtype: object

# %%
for i in temp:
    print(i[0][0])
    new_df['Заказ клиента'].append(pd.Series(i[0][0]))
